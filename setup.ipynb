# %%
pip install -e.
# Out:
# Obtaining file:///c:/Users/Visitor/Desktop/Orbittest/optics_gui_wx26_test
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from optics-gui==0.1.0) (2.5.1)
# Requirement already satisfied: pandas in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from optics-gui==0.1.0) (3.0.3)
# Requirement already satisfied: matplotlib in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from optics-gui==0.1.0) (3.11.1)
# Requirement already satisfied: cpymad in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from optics-gui==0.1.0) (1.19.0)
# Requirement already satisfied: minrpc>=0.1.0 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from cpymad->optics-gui==0.1.0) (0.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib->optics-gui==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib->optics-gui==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib->optics-gui==0.1.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib->optics-gui==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib->optics-gui==0.1.0) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib->optics-gui==0.1.0) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib->optics-gui==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib->optics-gui==0.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->optics-gui==0.1.0) (1.17.0)
# Requirement already satisfied: tzdata in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from pandas->optics-gui==0.1.0) (2026.3)
# Building wheels for collected packages: optics-gui
#   Building editable for optics-gui (pyproject.toml): started
#   Building editable for optics-gui (pyproject.toml): finished with status 'done'
#   Created wheel for optics-gui: filename=optics_gui-0.1.0-0.editable-py3-none-any.whl size=9081 sha256=6eea1af6779348dc6d735e7c4333dd36acb71f04e9f299427700b35527812739
#   Stored in directory: C:\Users\Visitor\AppData\Local\Temp\pip-ephem-wheel-cache-sc8o99s7\wheels\95\95\62\dc920d4342b0e6785e74dd760da6a67216085787b097415240
# Successfully built optics-gui
# Installing collected packages: optics-gui
#   Attempting uninstall: optics-gui
#     Found existing installation: optics-gui 0.1.0
#     Uninstalling optics-gui-0.1.0:
#       Successfully uninstalled optics-gui-0.1.0
# Successfully installed optics-gui-0.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\Visitor\Desktop\Orbittest\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd()
if repo_root.name == "12_IO":
    repo_root = repo_root.parents[1]
elif (repo_root / "Dev" / "12_IO").is_dir():
    pass

src_path = repo_root / "src"
if src_path.is_dir() and str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

RUN_FULL_MODEL = True
RUN_ORBIT_CORRECTION_EXAMPLE = True

print(f"repo_root = {repo_root}")
print(f"RUN_FULL_MODEL = {RUN_FULL_MODEL}")
print(f"RUN_ORBIT_CORRECTION_EXAMPLE = {RUN_ORBIT_CORRECTION_EXAMPLE}")
# Out:
# repo_root = c:\Users\Visitor\Desktop\Orbittest\optics_gui_wx26_test
# RUN_FULL_MODEL = True
# RUN_ORBIT_CORRECTION_EXAMPLE = True

# %%
import pandas as pd
import matplotlib.pyplot as plt

from optics_gui.cycle_time import RCSRamp
from optics_gui.machine_state import MachineState
from optics_gui.correctors import current_to_kick_rad, kick_rad_to_current
from optics_gui.errors import (
    read_error_table,
    summarise_error_table,
    write_zeroed_error_table_copy,
    zero_error_table_magnets,
)
from optics_gui.error_plots import error_table_to_misalignment_offsets, plot_error_table_misalignment_offsets
from optics_gui.tune import (
    build_tune_programme_table,
    build_working_point_table,
    generate_resonance_lines,
    evaluate_resonance_proximity,
    make_tune_diagram_inputs,
)
from optics_gui.snapshot import (
    SnapshotConfig,
    SnapshotSeriesConfig,
    SnapshotOrbitCorrectionConfig,
    build_machine_snapshot,
    build_full_cycle_snapshot_series,
    copy_snapshot_config,
)
from optics_gui.envelope import EnvelopeInputs, plot_envelope, plot_sigma, plot_envelope_comparison
from optics_gui.orbit_correction import (
    bpm_measurements_from_twiss,
    normalise_corrector_selection,
    plot_corrector_suggestions,
    plot_orbit_with_bpm,
)
from optics_gui.aperture import (
    read_source_aperture_csv,
    plot_aperture_envelope_with_margin,
    plot_margin,
)
from optics_gui.tune_plots import plot_tune_diagram_inputs
from optics_gui.io import (
    config_to_record,
    config_from_record,
    corrector_settings_from_table,
    normalise_bpm_table,
    normalise_corrector_table,
    snapshot_configs_from_table,
    write_snapshot_bundle,
    read_run_bundle,
    write_snapshot_config,
    read_snapshot_config,
    series_config_to_record,
    series_config_from_record,
    write_snapshot_series_config,
    read_snapshot_series_config,
)

print("Imports worked")
# Out:
# Imports worked

# %%
basic_config = SnapshotConfig(
    cycle_time_ms=0.0,
    requested_qx=4.31,
    requested_qy=3.83,
    output_dir=str(repo_root / "Dev" / "12_IO" / "student_runs"),
    run_envelope=False,
    run_aperture=False,
)

record = config_to_record(basic_config)
restored = config_from_record(record)

print(record["__type__"])
print(restored.resolved_label())
print(restored.requested_qx, restored.requested_qy)
# Out:
# SnapshotConfig
# nominal_0ms
# 4.31 3.83
